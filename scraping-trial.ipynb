# %%
# Import dependencies
from time import sleep
import pandas as pd
from splinter import Browser
from splinter.exceptions import ElementDoesNotExist
from webdriver_manager.chrome import ChromeDriverManager
from bs4 import BeautifulSoup as bs

# %%
executable_path = {'executable_path': ChromeDriverManager().install()}
browser = Browser('chrome', **executable_path, headless=False)
# Out:
# [WDM] - Current google-chrome version is 85.0.4183
# [WDM] - Get LATEST driver version for 85.0.4183
# [WDM] - Get LATEST driver version for 85.0.4183
# [WDM] - Trying to download new driver from http://chromedriver.storage.googleapis.com/85.0.4183.87/chromedriver_win32.zip
# [WDM] - Driver has been saved in cache [C:\Users\pooja\.wdm\drivers\chromedriver\win32\85.0.4183.87]

# %% [markdown]
# ## Extract: scrape animal data from zoo.org.au

# %%
zoo_url = "https://www.zoo.org.au/fighting-extinction/local-threatened-species/"

# Use splinter to navigate the site
browser.visit(zoo_url)

# %%
# Create BeautifulSoup object; parse with 'lxml'
html = browser.html
soup = bs(html, 'lxml')

# %%
# Retrieve the htmls of the links to each animal
animal_html_list = soup.find_all("div", class_="feature-tile__title")

# %%
# Retrieve the animal names in all of the above htmls
animal_list = []

for animal in animal_html_list:
    animal_list.append(animal.get_text().split("(")[0].strip())

# %%
animal_list
# Out:
# ['Alpine She-oak Skink',
#  'Baw Baw Frog',
#  'Brush-tailed Rock-wallaby',
#  'Eastern Barred Bandicoot',
#  'Giant Burrowing Frog',
#  'Golden-rayed Blue Butterfly',
#  'Grassland Earless Dragon',
#  'Guthega Skink',
#  'Helmeted Honeyeater',
#  'Key’s Matchstick Grasshopper',
#  'Large Brown Tree Frog',
#  "Leadbeater's Possum",
#  'Lord Howe Island Stick Insect',
#  'Mallee Emu-wren',
#  'Mountain Pygmy-possum',
#  'New Holland Mouse',
#  'Northern Corroboree Frog',
#  'Orange-bellied Parrot',
#  'Plains-wanderer',
#  'Regent Honeyeater',
#  'Smoky Mouse',
#  'Southern Bent-wing Bat',
#  'Southern Corroboree Frog',
#  'Spotted Tree Frog',
#  'Stuttering Barred Frog',
#  'Swift Parrot',
#  'Tasmanian Devil']

# %%
# Click the first link under "Learn More" to go to the first animal page
browser.links.find_by_partial_text("Learn More").click()

# %%
# Loop through all of the animals by interacting with the next element in navigation bar
animal_info_image_zoo = list()

for item in animal_list:

    sleep(1)
    html = browser.html
    soup = bs(html, 'lxml')

    # Retrieve the first animal image url
    image_url = soup.select_one("picture img")["src"]
    if image_url.startswith("/media"):
        full_image_url = f"https://www.zoo.org.au{image_url}"
        print(full_image_url)
    else:
        full_image_url = image_url
        print(full_image_url)

    # Retrieve the first animal image alternative
    image_alternative = soup.select_one("picture img")["alt"]
        
    # Retrieve the introduction paragraph
    intro = soup.find("p", class_="intro").text.strip()

    # Retrieve some info on threats
    try:
        threat_paragraph = soup.find("div", class_="row-wrapper--right-weighted-column").text.strip()
    except AttributeError:
        results = soup.find_all("p")
        threat_paragraph = [result.text.strip() for result in results][1:4]
        
    # Append a dictionary with the above info to a list
    animal_info_image_zoo.append({
        "animal_name": item,
        "image_url": full_image_url,
        "image_alternative": image_alternative,
        "introduction": intro,
        "threat_paragraph": threat_paragraph
    })

    # Click the next animal page in navigation bar down to the bottom of the page
    browser.find_by_xpath('//*[@id="main-content"]/nav/div/div/div/div[2]/nav/a[2]').click()
# Out:
# https://www.zoo.org.au/media/2050/1023_alpine_she-oak_skink_healesville_sanctuary1.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132131638000000000
# https://www.zoo.org.au/media/2052/21295_baw_baw_frog_melbourne_zoo1.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132131638840000000
# https://www.zoo.org.au/media/2045/21882_brush-tailed_rock-wallabies_healesville_sanctuary.jpg?center=0.46198830409356723,0.31833333333333336&mode=crop&quality=75&width=2000&height=570&rnd=132131636770000000
# https://www.zoo.org.au/media/2053/4376_eastern_barred_bandicoot_in_bandicoot_hideout_werribee_open_range_zoo.jpg?center=0.48333333333333334,0.37333333333333335&mode=crop&quality=75&width=2000&height=570&rnd=132131642280000000
# https://www.zoo.org.au/media/2056/23479_giant_burrowing_frog_-_credit_required_offsite1.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132131643480000000
# https://www.zoo.org.au/media/1703/animal-detail-page_0001_golden-rayed-blue-butterfly-credit-kate-pearce.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132127412220000000
# https://www.zoo.org.au/media/1716/23200_grassland_earless_dragon_melbourne_zoo.jpg?center=0.35260115606936415,0.59333333333333338&mode=crop&quality=75&width=2000&height=570&rnd=132127417720000000
# https://www.zoo.org.au/media/1980/10411_guthega_skink_baby_healesville_sanctuary.jpg?center=0.52631578947368418,0.26&mode=crop&quality=75&width=2000&height=570&rnd=132131628020000000
# https://www.zoo.org.au/media/1681/18660_juvenile_helmeted_honeyeater_healesville_sanctuary.jpg?center=0.29019607843137257,0.56333333333333335&mode=crop&quality=75&width=2000&height=570&rnd=132127394630000000
# https://www.zoo.org.au/media/1702/animal-detail-page_0000_keys-matchstick-grasshopper-credit-michael-kearney.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132127409400000000
# https://www.zoo.org.au/media/1701/animal-detail-page_0005_large-brown-tree-frog-creditmichael-mcfadden.jpg?center=0.3411764705882353,0.225&mode=crop&quality=75&width=2000&height=570&rnd=132127407870000000
# https://www.zoo.org.au/media/2057/22861_leadbeater_s_possum_monitoring_offsite.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132131644540000000
# https://www.zoo.org.au/media/1983/7061_lord_howe_island_stick_insect_melbourne_zoo1.jpg?center=0.631578947368421,0.61&mode=crop&quality=75&width=2000&height=570&rnd=132131632950000000
# https://www.zoo.org.au/media/1961/23483_mallee_emu-wren_offsite.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132131595290000000
# https://www.zoo.org.au/media/2058/16910_mountain_pygmy-possum_christmas_enrichment_2018_healesville_sanctuary.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132131645290000000
# https://www.zoo.org.au/media/1732/new-holland-mouse.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132127425380000000
# https://www.zoo.org.au/media/1671/14621_northern_corroboree_frog_healesville_sanctuary.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132127390300000000
# https://www.zoo.org.au/media/2059/22407_orange-bellied_parrot_healesville_sanctuary.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132131646350000000
# https://www.zoo.org.au/media/1761/11190_plains_wanderer_offsite.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132127434520000000
# https://www.zoo.org.au/media/2055/22249_regent_honeyeater_melbourne_zoo.jpg?center=0.42690058479532161,0.39666666666666667&mode=crop&quality=75&width=2000&height=570&rnd=132131643320000000
# https://www.zoo.org.au/media/1810/13940_smoky-mouse_healesville-sanctuary.jpg?center=0.50292397660818711,0.33&mode=crop&quality=75&width=2000&height=570&rnd=132127440630000000
# https://www.zoo.org.au/media/3866/9290_southern-bent-wing-bat_healesville-sanctuary.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132355004050000000
# https://www.zoo.org.au/media/2054/1550_southern_corroboree_frog_melbourne_zoo.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132131642710000000
# https://www.zoo.org.au/media/1815/2372_spotted_tree-frog_offsite1.jpg?center=0.37,0.49333333333333335&mode=crop&quality=75&width=2000&height=570&rnd=132127444450000000
# https://www.zoo.org.au/media/1816/22212_stuttering_frog_melbourne_zoo.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132127444780000000
# https://www.zoo.org.au/media/1960/23484_swift_parrot_offsite.jpg?center=0.27666666666666667,0.59666666666666668&mode=crop&quality=75&width=2000&height=570&rnd=132131594410000000
# https://www.zoo.org.au/media/1853/22521_tasmanian_devil_melbourne_zoo1.jpg?anchor=center&mode=crop&quality=75&width=2000&height=570&rnd=132127448850000000

# %% [markdown]
# ## Extract: scrape animal data from environment.vic.gov.au

# %%
# URL of page to be scraped
url = "https://www.environment.vic.gov.au/conserving-threatened-species/threatened-species"

# Use splinter to navigate the site
browser.visit(url)

# %%
# Create BeautifulSoup object; parse with 'lxml'
html = browser.html
soup = bs(html, 'lxml')

# %%
# Retrieve all text with links
text_with_links = soup.find_all(class_ = 'internal-link')

for text in text_with_links:
    print(text.get_text())
# Out:
# Caring for Our Environment - Faunal Emblems Program
# Baw Baw Frog
# Brush-tailed Rock-wallaby
# Eastern Barred Bandicoot
# Greater Glider
# Helmeted Honeyeater
# Hooded Plover
# Leadbeater's Possum
# Macquarie Perch (PDF, 397.0 KB)
# Mountain Pygmy-possum
# Orange-bellied Parrot
# Plains-wanderer
# Regent Honeyeater
# Mountain Swainson-pea Swainsona recta (PDF, 330.7 KB)
# Concave Pomaderris (Pomaderris subplicata) (PDF, 1.5 MB)
# Phantom Wattle  (Acacia phasmoides) (PDF, 331.8 KB)
# Stony Bush-pea (Pultanea lapidosa) (PDF, 2.7 MB)

# %%
# As we are only interested in fauna, we'll only keep animal names.
text_to_search = [text.get_text() for text in text_with_links][1: -4]
text_to_search
# Out:
# ['Baw Baw Frog',
#  'Brush-tailed Rock-wallaby',
#  'Eastern Barred Bandicoot',
#  'Greater Glider',
#  'Helmeted Honeyeater',
#  'Hooded Plover',
#  "Leadbeater's Possum",
#  'Macquarie Perch (PDF, 397.0 KB)',
#  'Mountain Pygmy-possum',
#  'Orange-bellied Parrot',
#  'Plains-wanderer',
#  'Regent Honeyeater']

# %%
animal_info_image_environment = []

for i in range(len(text_to_search)):
    
    # Click each of the links to the threatened species.
    browser.find_by_xpath(f'//*[@id="content_container_70299"]/p[{i+1}]/a').click()
    sleep(1)
    html = browser.html
    soup = bs(html, 'lxml')

    # Escape from the page with pdf file (not html)
    if text_to_search[i] == "Macquarie Perch (PDF, 397.0 KB)":
        browser.visit(url)
        sleep(1)
        
    else:
        # Retrieve animal image url if available
        try:
            full_image_url = soup.select_one("div.content-wrapper__col-content img")["src"]
            print(full_image_url)
        except TypeError:
            full_image_url = None

        # Retrieve the species info section
        try:
            intro = soup.find("div", class_="col-xs-12 col-sm-6 feature-box").text.strip()
        except AttributeError:
            results = soup.find_all("div", class_="row top-xs")
            intro = [result.text.strip() for result in results][0]

        # Retrieve the threat info section
        try:
            threat_paragraph = soup.find("div", class_="col-xs-12 feature-box").text.strip()
        except AttributeError:
            results = soup.find_all("div", class_="row top-xs")
            threat_paragraph = [result.text.strip() for result in results][1]

        # Append the dictionary with the above info to a list
        animal_info_image_environment.append({
            "animal_name": text_to_search[i],
            "image_url": full_image_url,
            "image_alternative": text_to_search[i],
            "introduction": intro,
            "threat_paragraph": threat_paragraph
        })
        
        # Back to the starting url
        browser.visit(url) 
        sleep(1)
# Out:
# https://www.environment.vic.gov.au/__data/assets/image/0027/429534/Baw-Baw-Frog.jpg
# https://www.environment.vic.gov.au/__data/assets/image/0030/428556/Eastern-Barred-Bandicoot.jpg
# https://www.environment.vic.gov.au/__data/assets/image/0024/440367/Greater-Glider-black-Steve-Smith.jpg
# https://www.environment.vic.gov.au/__data/assets/image/0031/427846/Helmeted-Honeyeater.jpg
# https://www.environment.vic.gov.au/__data/assets/image/0030/428808/IMG_3825lr.jpg
# https://www.environment.vic.gov.au/__data/assets/image/0033/427983/Lowland-LBP_Zoos-Victoria.JPG
# https://www.environment.vic.gov.au/__data/assets/image/0026/428930/28310791230_680f9be730_k.jpg
# https://www.environment.vic.gov.au/__data/assets/image/0024/428640/OBP.jpg
# https://www.environment.vic.gov.au/__data/assets/image/0029/428618/Plains-wanderer.jpg
# https://www.environment.vic.gov.au/__data/assets/image/0025/429514/2015-Yellow-Yellow-Red-Metal-YYRM_Dean-Ingwersen.jpg

# %%
# Quit the browser after scraping
browser.quit()

# %% [markdown]
# ## Consolidate data scraped from zoo.org.au and environment.vic.gov.au

# %%
# Overview of data scraped from environment.vic.gov.au
animal_info_image_environment_df = pd.DataFrame(animal_info_image_environment)
animal_info_image_environment_df.head()
# Out:
#                  animal_name  \
# 0               Baw Baw Frog
# 1  Brush-tailed Rock-wallaby
# 2   Eastern Barred Bandicoot
# 3             Greater Glider
# 4        Helmeted Honeyeater
#
#                                            image_url  \
# 0  https://www.environment.vic.gov.au/__data/asse...
# 1                                               None
# 2  https://www.environment.vic.gov.au/__data/asse...
# 3  https://www.environment.vic.gov.au/__data/asse...
# 4  https://www.environment.vic.gov.au/__data/asse...
#
#            image_alternative  \
# 0               Baw Baw Frog
# 1  Brush-tailed Rock-wallaby
# 2   Eastern Barred Bandicoot
# 3             Greater Glider
# 4        Helmeted Honeyeater
#
#                                         introduction  \
# 0  Species information\n\nEndemic to the Mt Baw B...
# 1  Species Information\n\nThe Southern Evolutiona...
# 2  Species information\n\nThe Eastern Barred Band...
# 3
# 4  Species information\n\nThis subspecies of the ...
#
#                                     threat_paragraph
# 0  Threats\n\nThe wild population of Baw Baw Frog...
# 1  Species Information\n\nThe Southern Evolutiona...
# 2  Threats\n\nLoss of their grassland habitat and...
# 3  Species InformationThe Greater Glider is Austr...
# 4  Threats\n\nAs numbers of Helmeted Honeyeaters ...

# %%
# Overview of data scraped from zoo.org.au
animal_info_image_zoo_df = pd.DataFrame(animal_info_image_zoo)
animal_info_image_zoo_df.head()
# Out:
#                  animal_name  \
# 0       Alpine She-oak Skink
# 1               Baw Baw Frog
# 2  Brush-tailed Rock-wallaby
# 3   Eastern Barred Bandicoot
# 4       Giant Burrowing Frog
#
#                                            image_url  \
# 0  https://www.zoo.org.au/media/2050/1023_alpine_...
# 1  https://www.zoo.org.au/media/2052/21295_baw_ba...
# 2  https://www.zoo.org.au/media/2045/21882_brush-...
# 3  https://www.zoo.org.au/media/2053/4376_eastern...
# 4  https://www.zoo.org.au/media/2056/23479_giant_...
#
#                                    image_alternative  \
# 0  Alpine She-oak Skink sunning it self on a rock...
# 1  Baw Baw Frog resting in bright green moss. Loo...
# 2  Brush Tailed Rock Wallabies resting in the grass.
# 3  Small Eastern Barred Bandicoot side view forag...
# 4  Giant Burrowing Frog on wet rocks side view. T...
#
#                                         introduction  \
# 0  Found in only a few locations in Victoria and ...
# 1  All estimates point to extinction in the wild ...
# 2  In Victoria, the Brush-tailed Rock-wallaby now...
# 3  The Eastern Barred Bandicoot is listed as exti...
# 4  Although we know that populations of the Giant...
#
#                                     threat_paragraph
# 0  Major threats\nFire is a huge danger to the Al...
# 1  Major threats\nThe loss of the Baw Baw Frog is...
# 2  Major threats \nChanges to habitat and the imp...
# 3  The plan for recovery\nZoos Victoria has partn...
# 4  [Over the next five years, Zoos Victoria will ...

# %%
# Outer merge to see which animals in the zoo site but not in the environment site and vice versa
animal_info_image_df = pd.merge(animal_info_image_zoo_df, animal_info_image_environment_df,
                                on="animal_name", how="outer", suffixes=("_zoo", "_envi"))
animal_info_image_df
# Out:
#                       animal_name  \
# 0            Alpine She-oak Skink
# 1                    Baw Baw Frog
# 2       Brush-tailed Rock-wallaby
# 3        Eastern Barred Bandicoot
# 4            Giant Burrowing Frog
# 5     Golden-rayed Blue Butterfly
# 6        Grassland Earless Dragon
# 7                   Guthega Skink
# 8             Helmeted Honeyeater
# 9    Key’s Matchstick Grasshopper
# 10          Large Brown Tree Frog
# 11            Leadbeater's Possum
# 12  Lord Howe Island Stick Insect
# 13                Mallee Emu-wren
# 14          Mountain Pygmy-possum
# 15              New Holland Mouse
# 16       Northern Corroboree Frog
# 17          Orange-bellied Parrot
# 18                Plains-wanderer
# 19              Regent Honeyeater
# 20                    Smoky Mouse
# 21         Southern Bent-wing Bat
# 22       Southern Corroboree Frog
# 23              Spotted Tree Frog
# 24         Stuttering Barred Frog
# 25                   Swift Parrot
# 26                Tasmanian Devil
# 27                 Greater Glider
# 28                  Hooded Plover
#
#                                         image_url_zoo  \
# 0   https://www.zoo.org.au/media/2050/1023_alpine_...
# 1   https://www.zoo.org.au/media/2052/21295_baw_ba...
# 2   https://www.zoo.org.au/media/2045/21882_brush-...
# 3   https://www.zoo.org.au/media/2053/4376_eastern...
# 4   https://www.zoo.org.au/media/2056/23479_giant_...
# 5   https://www.zoo.org.au/media/1703/animal-detai...
# 6   https://www.zoo.org.au/media/1716/23200_grassl...
# 7   https://www.zoo.org.au/media/1980/10411_gutheg...
# 8   https://www.zoo.org.au/media/1681/18660_juveni...
# 9   https://www.zoo.org.au/media/1702/animal-detai...
# 10  https://www.zoo.org.au/media/1701/animal-detai...
# 11  https://www.zoo.org.au/media/2057/22861_leadbe...
# 12  https://www.zoo.org.au/media/1983/7061_lord_ho...
# 13  https://www.zoo.org.au/media/1961/23483_mallee...
# 14  https://www.zoo.org.au/media/2058/16910_mounta...
# 15  https://www.zoo.org.au/media/1732/new-holland-...
# 16  https://www.zoo.org.au/media/1671/14621_northe...
# 17  https://www.zoo.org.au/media/2059/22407_orange...
# 18  https://www.zoo.org.au/media/1761/11190_plains...
# 19  https://www.zoo.org.au/media/2055/22249_regent...
# 20  https://www.zoo.org.au/media/1810/13940_smoky-...
# 21  https://www.zoo.org.au/media/3866/9290_souther...
# 22  https://www.zoo.org.au/media/2054/1550_souther...
# 23  https://www.zoo.org.au/media/1815/2372_spotted...
# 24  https://www.zoo.org.au/media/1816/22212_stutte...
# 25  https://www.zoo.org.au/media/1960/23484_swift_...
# 26  https://www.zoo.org.au/media/1853/22521_tasman...
# 27                                                NaN
# 28                                                NaN
#
#                                 image_alternative_zoo  \
# 0   Alpine She-oak Skink sunning it self on a rock...
# 1   Baw Baw Frog resting in bright green moss. Loo...
# 2   Brush Tailed Rock Wallabies resting in the grass.
# 3   Small Eastern Barred Bandicoot side view forag...
# 4   Giant Burrowing Frog on wet rocks side view. T...
# 5   Golden Rayed Blue Butterfly resting with wings...
# 6   Grassland Earless Dragon lizard side view look...
# 7   Baby Guthega Skink side view. Lizard looking t...
# 8   Juvenile Helmeted Honeyeater standing on a tre...
# 9   Key's Matchstick Grasshopper. Its brown with a...
# 10  Close up side view of a large Brown Tree Frog ...
# 11  Close up view of the face of a Leadbeater Poss...
# 12  Lord Howe Island Stick Insect on a persons han...
# 13  Mallee Emu-wren in long dry grass looking at t...
# 14  Mountain Pygmy Possum standing on its hind leg...
# 15  New Holland Mouse getting a health check wrapp...
# 16  Northern Corroboree Frog with its vivid yellow...
# 17  Orange Bellied Parrot side view looking to the...
# 18  Plains Wanderer bird standing in dry grass. Si...
# 19  Regent Honeyeater bird on a branch looking dow...
# 20  Smoky Mouse in a sandy habitat with grass and ...
# 21
# 22  Southern Corroboree Frog standing on pale gree...
# 23  Spotted Tree Frog is gripping a fern leaf look...
# 24  Stuttering Frog sitting on green moss. Frog is...
# 25  Green Swift Parrot perched on a branch looking...
# 26  Tasmanian Devil standing on a log with its mou...
# 27                                                NaN
# 28                                                NaN
#
#                                      introduction_zoo  \
# 0   Found in only a few locations in Victoria and ...
# 1   All estimates point to extinction in the wild ...
# 2   In Victoria, the Brush-tailed Rock-wallaby now...
# 3   The Eastern Barred Bandicoot is listed as exti...
# 4   Although we know that populations of the Giant...
# 5   This Victorian butterfly is critically endange...
# 6   The Grassland Earless Dragon has not appeared ...
# 7   The Guthega Skink is endangered in Victoria an...
# 8   The Helmeted Honeyeater, the bird emblem for V...
# 9   This distinctive grasshopper is flightless and...
# 10  The Large Brown Tree Frog is one of the least ...
# 11  Once thought to be extinct, the Leadbeater's P...
# 12  Once considered extinct, the Lord Howe Island ...
# 13  The Mallee Emu-wren is particularly vulnerable...
# 14  Mountain Pygmy-possums were thought to be exti...
# 15  The New Holland Mouse is classified as extinct...
# 16  This little frog’s vivid lime green stripes se...
# 17  One of only a few migratory parrot species in ...
# 18  In evolutionary terms, Plains-wanderers are on...
# 19  The Regent Honeyeater has been in decline sinc...
# 20  The Smoky Mouse, once commonly found in south ...
# 21      This tiny micro-bat is critically endangered.
# 22  One of Australia’s best known frogs is critica...
# 23  Populations of the Spotted Tree Frog have decl...
# 24  Populations of Stuttering Barred Frogs are fas...
# 25         The Swift Parrot is critically endangered.
# 26  Now listed as endangered, the Tasmanian Devil ...
# 27                                                NaN
# 28                                                NaN
#
#                                  threat_paragraph_zoo  \
# 0   Major threats\nFire is a huge danger to the Al...
# 1   Major threats\nThe loss of the Baw Baw Frog is...
# 2   Major threats \nChanges to habitat and the imp...
# 3   The plan for recovery\nZoos Victoria has partn...
# 4   [Over the next five years, Zoos Victoria will ...
# 5   [It lives in the narrow bands of remnant flood...
# 6   The plan for recovery\nZoos Victoria has been ...
# 7   Major threats\nHabitat disturbance caused by g...
# 8   Major threats\nLoss of habitat is the primary ...
# 9   [The Key’s Matchstick Grasshopper hasn’t been ...
# 10  [The mating call of the Large Brown Tree Frog ...
# 11  The major threats\nThe loss of hollow-bearing ...
# 12  The major threats \nThe Lord Howe Island Stick...
# 13  [In fact, it was a series of fires that caused...
# 14  The major threats \nClimate change, the loss o...
# 15  The major threats\nThe New Holland Mouse is in...
# 16  The major threats\nThe disease Chytridiomycosi...
# 17  The major threats\nOne of the main threats to ...
# 18  The major threats\nThe major threat to the sur...
# 19  The major threats\nThe loss of the Box-Ironbar...
# 20  [The Smoky Mouse eats seeds and fruit in summe...
# 21  The major threats\nAlthough they are under thr...
# 22  Major threats\nThe main threat to the Southern...
# 23  Major threats\nLike most Australian and intern...
# 24  Major threats\nLogging, animal grazing and lan...
# 25  [Unless we can solve the issues surrounding it...
# 26  Major threats\nThe survival of Tasmanian Devil...
# 27                                                NaN
# 28                                                NaN
#
#                                        image_url_envi  \
# 0                                                 NaN
# 1   https://www.environment.vic.gov.au/__data/asse...
# 2                                                None
# 3   https://www.environment.vic.gov.au/__data/asse...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   https://www.environment.vic.gov.au/__data/asse...
# 9                                                 NaN
# 10                                                NaN
# 11  https://www.environment.vic.gov.au/__data/asse...
# 12                                                NaN
# 13                                                NaN
# 14  https://www.environment.vic.gov.au/__data/asse...
# 15                                                NaN
# 16                                                NaN
# 17  https://www.environment.vic.gov.au/__data/asse...
# 18  https://www.environment.vic.gov.au/__data/asse...
# 19  https://www.environment.vic.gov.au/__data/asse...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  https://www.environment.vic.gov.au/__data/asse...
# 28  https://www.environment.vic.gov.au/__data/asse...
#
#        image_alternative_envi  \
# 0                         NaN
# 1                Baw Baw Frog
# 2   Brush-tailed Rock-wallaby
# 3    Eastern Barred Bandicoot
# 4                         NaN
# 5                         NaN
# 6                         NaN
# 7                         NaN
# 8         Helmeted Honeyeater
# 9                         NaN
# 10                        NaN
# 11        Leadbeater's Possum
# 12                        NaN
# 13                        NaN
# 14      Mountain Pygmy-possum
# 15                        NaN
# 16                        NaN
# 17      Orange-bellied Parrot
# 18            Plains-wanderer
# 19          Regent Honeyeater
# 20                        NaN
# 21                        NaN
# 22                        NaN
# 23                        NaN
# 24                        NaN
# 25                        NaN
# 26                        NaN
# 27             Greater Glider
# 28              Hooded Plover
#
#                                     introduction_envi  \
# 0                                                 NaN
# 1   Species information\n\nEndemic to the Mt Baw B...
# 2   Species Information\n\nThe Southern Evolutiona...
# 3   Species information\n\nThe Eastern Barred Band...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Species information\n\nThis subspecies of the ...
# 9                                                 NaN
# 10                                                NaN
# 11  Species Information\n\nThe Leadbeater’s Possum...
# 12                                                NaN
# 13                                                NaN
# 14  Species Information\n\nThe Mountain Pygmy-poss...
# 15                                                NaN
# 16                                                NaN
# 17  Species Information\n\nThe Orange-bellied Parr...
# 18  Species Information\n\nThis elusive bird lives...
# 19  Species information\n\nRegent Honeyeater’s are...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27
# 28  Species Information\n\nHooded Plovers are a re...
#
#                                 threat_paragraph_envi
# 0                                                 NaN
# 1   Threats\n\nThe wild population of Baw Baw Frog...
# 2   Species Information\n\nThe Southern Evolutiona...
# 3   Threats\n\nLoss of their grassland habitat and...
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8   Threats\n\nAs numbers of Helmeted Honeyeaters ...
# 9                                                 NaN
# 10                                                NaN
# 11  Threats\n\nThe lowland population of the Leadb...
# 12                                                NaN
# 13                                                NaN
# 14  Threats\n\nThere are around 2000 Mountain Pygm...
# 15                                                NaN
# 16                                                NaN
# 17  Threats\n\nThis species is at serious risk of ...
# 18  Threats\n\nMuch of the Plains-wanderer's range...
# 19  Regent Honeyeater Release & Community Monitori...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  Species InformationThe Greater Glider is Austr...
# 28  Threats\n\nHooded Plovers often share their oc...

# %%
# Retrieve the animal list in the environment site but not in the zoo site
animals_in_envi_not_in_zoo = animal_info_image_df[animal_info_image_df[
    "image_url_zoo"].isnull()]["animal_name"].to_list()
animals_in_envi_not_in_zoo
# Out:
# ['Greater Glider', 'Hooded Plover']

# %%
# Extract the data of the animals in the environment site but not in the zoo site
animals_in_envi_add_to_zoo = animal_info_image_environment_df[
    animal_info_image_environment_df["animal_name"].isin(animals_in_envi_not_in_zoo)]
animals_in_envi_add_to_zoo
# Out:
#       animal_name                                          image_url  \
# 3  Greater Glider  https://www.environment.vic.gov.au/__data/asse...
# 5   Hooded Plover  https://www.environment.vic.gov.au/__data/asse...
#
#   image_alternative                                       introduction  \
# 3    Greater Glider
# 5     Hooded Plover  Species Information\n\nHooded Plovers are a re...
#
#                                     threat_paragraph
# 3  Species InformationThe Greater Glider is Austr...
# 5  Threats\n\nHooded Plovers often share their oc...

# %%
# Consolidate data from both sites (keeping all of the ones in the zoo site and adding the extra in the environment site)
final_animal_image_df = pd.concat([animal_info_image_zoo_df, animals_in_envi_add_to_zoo], axis=0)
final_animal_image_df
# Out:
#                       animal_name  \
# 0            Alpine She-oak Skink
# 1                    Baw Baw Frog
# 2       Brush-tailed Rock-wallaby
# 3        Eastern Barred Bandicoot
# 4            Giant Burrowing Frog
# 5     Golden-rayed Blue Butterfly
# 6        Grassland Earless Dragon
# 7                   Guthega Skink
# 8             Helmeted Honeyeater
# 9    Key’s Matchstick Grasshopper
# 10          Large Brown Tree Frog
# 11            Leadbeater's Possum
# 12  Lord Howe Island Stick Insect
# 13                Mallee Emu-wren
# 14          Mountain Pygmy-possum
# 15              New Holland Mouse
# 16       Northern Corroboree Frog
# 17          Orange-bellied Parrot
# 18                Plains-wanderer
# 19              Regent Honeyeater
# 20                    Smoky Mouse
# 21         Southern Bent-wing Bat
# 22       Southern Corroboree Frog
# 23              Spotted Tree Frog
# 24         Stuttering Barred Frog
# 25                   Swift Parrot
# 26                Tasmanian Devil
# 3                  Greater Glider
# 5                   Hooded Plover
#
#                                             image_url  \
# 0   https://www.zoo.org.au/media/2050/1023_alpine_...
# 1   https://www.zoo.org.au/media/2052/21295_baw_ba...
# 2   https://www.zoo.org.au/media/2045/21882_brush-...
# 3   https://www.zoo.org.au/media/2053/4376_eastern...
# 4   https://www.zoo.org.au/media/2056/23479_giant_...
# 5   https://www.zoo.org.au/media/1703/animal-detai...
# 6   https://www.zoo.org.au/media/1716/23200_grassl...
# 7   https://www.zoo.org.au/media/1980/10411_gutheg...
# 8   https://www.zoo.org.au/media/1681/18660_juveni...
# 9   https://www.zoo.org.au/media/1702/animal-detai...
# 10  https://www.zoo.org.au/media/1701/animal-detai...
# 11  https://www.zoo.org.au/media/2057/22861_leadbe...
# 12  https://www.zoo.org.au/media/1983/7061_lord_ho...
# 13  https://www.zoo.org.au/media/1961/23483_mallee...
# 14  https://www.zoo.org.au/media/2058/16910_mounta...
# 15  https://www.zoo.org.au/media/1732/new-holland-...
# 16  https://www.zoo.org.au/media/1671/14621_northe...
# 17  https://www.zoo.org.au/media/2059/22407_orange...
# 18  https://www.zoo.org.au/media/1761/11190_plains...
# 19  https://www.zoo.org.au/media/2055/22249_regent...
# 20  https://www.zoo.org.au/media/1810/13940_smoky-...
# 21  https://www.zoo.org.au/media/3866/9290_souther...
# 22  https://www.zoo.org.au/media/2054/1550_souther...
# 23  https://www.zoo.org.au/media/1815/2372_spotted...
# 24  https://www.zoo.org.au/media/1816/22212_stutte...
# 25  https://www.zoo.org.au/media/1960/23484_swift_...
# 26  https://www.zoo.org.au/media/1853/22521_tasman...
# 3   https://www.environment.vic.gov.au/__data/asse...
# 5   https://www.environment.vic.gov.au/__data/asse...
#
#                                     image_alternative  \
# 0   Alpine She-oak Skink sunning it self on a rock...
# 1   Baw Baw Frog resting in bright green moss. Loo...
# 2   Brush Tailed Rock Wallabies resting in the grass.
# 3   Small Eastern Barred Bandicoot side view forag...
# 4   Giant Burrowing Frog on wet rocks side view. T...
# 5   Golden Rayed Blue Butterfly resting with wings...
# 6   Grassland Earless Dragon lizard side view look...
# 7   Baby Guthega Skink side view. Lizard looking t...
# 8   Juvenile Helmeted Honeyeater standing on a tre...
# 9   Key's Matchstick Grasshopper. Its brown with a...
# 10  Close up side view of a large Brown Tree Frog ...
# 11  Close up view of the face of a Leadbeater Poss...
# 12  Lord Howe Island Stick Insect on a persons han...
# 13  Mallee Emu-wren in long dry grass looking at t...
# 14  Mountain Pygmy Possum standing on its hind leg...
# 15  New Holland Mouse getting a health check wrapp...
# 16  Northern Corroboree Frog with its vivid yellow...
# 17  Orange Bellied Parrot side view looking to the...
# 18  Plains Wanderer bird standing in dry grass. Si...
# 19  Regent Honeyeater bird on a branch looking dow...
# 20  Smoky Mouse in a sandy habitat with grass and ...
# 21
# 22  Southern Corroboree Frog standing on pale gree...
# 23  Spotted Tree Frog is gripping a fern leaf look...
# 24  Stuttering Frog sitting on green moss. Frog is...
# 25  Green Swift Parrot perched on a branch looking...
# 26  Tasmanian Devil standing on a log with its mou...
# 3                                      Greater Glider
# 5                                       Hooded Plover
#
#                                          introduction  \
# 0   Found in only a few locations in Victoria and ...
# 1   All estimates point to extinction in the wild ...
# 2   In Victoria, the Brush-tailed Rock-wallaby now...
# 3   The Eastern Barred Bandicoot is listed as exti...
# 4   Although we know that populations of the Giant...
# 5   This Victorian butterfly is critically endange...
# 6   The Grassland Earless Dragon has not appeared ...
# 7   The Guthega Skink is endangered in Victoria an...
# 8   The Helmeted Honeyeater, the bird emblem for V...
# 9   This distinctive grasshopper is flightless and...
# 10  The Large Brown Tree Frog is one of the least ...
# 11  Once thought to be extinct, the Leadbeater's P...
# 12  Once considered extinct, the Lord Howe Island ...
# 13  The Mallee Emu-wren is particularly vulnerable...
# 14  Mountain Pygmy-possums were thought to be exti...
# 15  The New Holland Mouse is classified as extinct...
# 16  This little frog’s vivid lime green stripes se...
# 17  One of only a few migratory parrot species in ...
# 18  In evolutionary terms, Plains-wanderers are on...
# 19  The Regent Honeyeater has been in decline sinc...
# 20  The Smoky Mouse, once commonly found in south ...
# 21      This tiny micro-bat is critically endangered.
# 22  One of Australia’s best known frogs is critica...
# 23  Populations of the Spotted Tree Frog have decl...
# 24  Populations of Stuttering Barred Frogs are fas...
# 25         The Swift Parrot is critically endangered.
# 26  Now listed as endangered, the Tasmanian Devil ...
# 3
# 5   Species Information\n\nHooded Plovers are a re...
#
#                                      threat_paragraph
# 0   Major threats\nFire is a huge danger to the Al...
# 1   Major threats\nThe loss of the Baw Baw Frog is...
# 2   Major threats \nChanges to habitat and the imp...
# 3   The plan for recovery\nZoos Victoria has partn...
# 4   [Over the next five years, Zoos Victoria will ...
# 5   [It lives in the narrow bands of remnant flood...
# 6   The plan for recovery\nZoos Victoria has been ...
# 7   Major threats\nHabitat disturbance caused by g...
# 8   Major threats\nLoss of habitat is the primary ...
# 9   [The Key’s Matchstick Grasshopper hasn’t been ...
# 10  [The mating call of the Large Brown Tree Frog ...
# 11  The major threats\nThe loss of hollow-bearing ...
# 12  The major threats \nThe Lord Howe Island Stick...
# 13  [In fact, it was a series of fires that caused...
# 14  The major threats \nClimate change, the loss o...
# 15  The major threats\nThe New Holland Mouse is in...
# 16  The major threats\nThe disease Chytridiomycosi...
# 17  The major threats\nOne of the main threats to ...
# 18  The major threats\nThe major threat to the sur...
# 19  The major threats\nThe loss of the Box-Ironbar...
# 20  [The Smoky Mouse eats seeds and fruit in summe...
# 21  The major threats\nAlthough they are under thr...
# 22  Major threats\nThe main threat to the Southern...
# 23  Major threats\nLike most Australian and intern...
# 24  Major threats\nLogging, animal grazing and lan...
# 25  [Unless we can solve the issues surrounding it...
# 26  Major threats\nThe survival of Tasmanian Devil...
# 3   Species InformationThe Greater Glider is Austr...
# 5   Threats\n\nHooded Plovers often share their oc...

# %%
# Export to csv for merging against the vba fauna data
final_animal_image_df.to_csv("../data/animal_image_to_merge.csv", index=False)
